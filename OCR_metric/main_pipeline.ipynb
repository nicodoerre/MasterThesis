# %%
from pipeline import calc_score_v2

# %%
gt_img_path = 'test_imgs/HR/pie_chart_20250519_081946_9afe32b4.png'
sr_img_path = 'test_imgs/SR/liif/pc.png'

# %%
calc_score_v2(gt_img_path, sr_img_path, vis=True, bb_name='bp2')
# Out:
# Sample detected bounding boxes (x, y, w, h):
# [(456, 48, 88, 32), (624, 136, 93, 16), (726, 136, 53, 16), (276, 169, 93, 16), (83, 400, 116, 20)]
# Sample detected texts:
# ['Data', 'Reaction', 'Time', 'Contrast', 'Brightness']
# Sample OCR Results from Crops:
#
# --- Crop 1 ---
# GT Text: Data
# SR Text: Data
#
# --- Crop 2 ---
# GT Text: Reaction
# SR Text: ReEAacTION
#
# --- Crop 3 ---
# GT Text: Time
# SR Text: Time
#
# --- Crop 4 ---
# GT Text: Contrast
# SR Text: (Contrast
#
# --- Crop 5 ---
# GT Text: Brightness
# SR Text: brightness
#
# --- Crop 6 ---
# GT Text: Level
# SR Text: | evel
#
# --- Crop 7 ---
# GT Text: Reaction
# SR Text: Reaction
#
# --- Crop 8 ---
# GT Text: Time
# SR Text: Time
#
# --- Crop 9 ---
# GT Text: Contrast
# SR Text: (Contrast
#
# --- Crop 10 ---
# GT Text: Brightness
# SR Text: Brightness
#
# --- Crop 1 ---
# GT: Data
# SR: Data
# CER: 0.000, WER: 0.000, Coverage: 1.000, Soft Coverage: 1.000, Classic Coverage: 1.000
# ...
